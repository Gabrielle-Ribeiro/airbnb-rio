# %% [markdown]
# # Airbnb no Rio de Janeiro - EDA e Visualização

# %% [markdown]
# Os dados desse projeto foram retirados do site: [Inside Airbnb](http://insideairbnb.com/get-the-data.html), que disponibliza datasets de dados coletados do próprio site do Airbnb.
#
# Foi utilizado um dataset referente aos dados de Airbnb no Rio de Janeiro - RJ.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/cleaned_listings.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     id                                               name  \
# 0           0  17878  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1           1  24480   Nice and cozy near Ipanema Beach, w/ home office
# 2           2  25026          Beautiful Modern Decorated Studio in Copa
# 3           3  35636                   Cosy flat close to Ipanema beach
# 4           4  35764     COPACABANA SEA BREEZE  -  RIO - 20 X Superhost
#
#    host_id neighbourhood_cleansed  latitude  longitude  \
# 0    68997             Copacabana -22.96599  -43.17940
# 1    99249                Ipanema -22.98405  -43.20189
# 2   102840             Copacabana -22.97735  -43.19105
# 3   153232                Ipanema -22.98839  -43.19232
# 4   153691             Copacabana -22.98107  -43.19136
#
#                 property_type        room_type  accommodates  ... bedrooms  \
# 0  Entire condominium (condo)  Entire home/apt             5  ...      2.0
# 1          Entire rental unit  Entire home/apt             2  ...      1.0
# 2          Entire rental unit  Entire home/apt             2  ...      1.0
# 3          Entire rental unit  Entire home/apt             2  ...      1.0
# 4                 Entire loft  Entire home/apt             2  ...      1.0
#
#    beds  price  minimum_nights  maximum_nights  number_of_reviews  \
# 0   2.0  350.0               5             180                266
# 1   1.0  296.0               3              90                 85
# 2   1.0  168.0               4              90                238
# 3   1.0  278.0               2              89                181
# 4   1.0  150.0               3              15                373
#
#    reviews_per_month  bathrooms_number  bathroom_is_shared  bathrooms_type
# 0               2.07               1.0                   0            bath
# 1               0.85               1.0                   0            bath
# 2               1.84               1.0                   0            bath
# 3               1.90               1.5                   0            bath
# 4               3.05               1.5                   0            bath
#
# [5 rows x 21 columns]
